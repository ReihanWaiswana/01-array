# %% [markdown]
# <a href="https://colab.research.google.com/github/ReihanWaiswana/01-array/blob/main/Soal_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Array Nilai

# %%
import numpy as np

#Memakai nilai yang tadi sudah diinput di file Soal_01
nilai = np.array([90, 78, 98, 56, 67, 54, 70, 60, 49, 95])
print(("Daftar Nilai : "), nilai)

nilaiTertinggi = max(nilai)
nilaiTerendah = min(nilai)

lulus = 0
for n in nilai:
  if n >= 60:
    lulus += 1

tidakLulus = len(nilai)-lulus
# Out:
# Daftar Nilai :  [90 78 98 56 67 54 70 60 49 95]
